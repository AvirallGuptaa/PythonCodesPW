# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x="tip",y="total_bill",data=df,hue="day")

# %%
sns.scatterplot(x="tip",y="total_bill",data=df,hue="smoker")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(x=df["tip"],y=df["total_bill"],data=df,hue="sex")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.relplot(x="tip",y="total_bill",data=df,hue="size")

# %%
sns.relplot(x="tip",y="total_bill",data=df,style="sex",hue="smoker")

# %%
time=np.arange(500)
value=np.random.randn(500).cumsum()
df=pd.DataFrame({"time":time,"value":value})

# %%
df
# Out:
#      time      value
# 0       0   0.015108
# 1       1   0.061595
# 2       2  -0.453263
# 3       3  -0.692714
# 4       4  -0.765515
# ..    ...        ...
# 495   495  12.703079
# 496   496  12.745796
# 497   497  13.246348
# 498   498  14.171820
# 499   499  14.108743
#
# [500 rows x 2 columns]

# %%
sns.relplot(x="time",y="value",kind="line",data=df,sort=True)

# %%
df=sns.load_dataset("fmri")

# %%
df
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x="timepoint",y="signal",kind="line",data=df,style="region",hue="event")

# %%
tips=sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x="total_bill",y="tip",data=tips,hue="smoker",col="time")

# %%
sns.catplot(y="total_bill",x="day",data=tips,hue="smoker",kind="swarm")

# %%
sns.catplot(y="total_bill",x="day",data=tips,hue="smoker",kind="box")

# %%
sns.catplot(y="total_bill",x="day",data=tips,hue="smoker",kind="violin")

# %%
sns.catplot(y="total_bill",x="day",data=tips,hue="smoker",kind="boxen")

# %%
sns.barplot(y="total_bill",x="day",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.jointplot(y="total_bill",x="day",data=tips)

# %%
sns.pairplot(tips,hue="smoker")
