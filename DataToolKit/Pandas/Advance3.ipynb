# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv")

# %%
df1=df[["Name","Age","Sex"]][0:5]

# %%
df1
# Out:
#                                                 Name   Age     Sex
# 0                            Braund, Mr. Owen Harris  22.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                             Heikkinen, Miss. Laina  26.0  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                           Allen, Mr. William Henry  35.0    male

# %%
df2=df[["Name","Age","Sex"]][5:10]

# %%
df2
# Out:
#                                                 Name   Age     Sex
# 5                                   Moran, Mr. James   NaN    male
# 6                            McCarthy, Mr. Timothy J  54.0    male
# 7                     Palsson, Master. Gosta Leonard   2.0    male
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0  female
# 9                Nasser, Mrs. Nicholas (Adele Achem)  14.0  female

# %%
pd.concat([df1,df2],axis=0)
# Out:
#                                                 Name   Age     Sex
# 0                            Braund, Mr. Owen Harris  22.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                             Heikkinen, Miss. Laina  26.0  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                           Allen, Mr. William Henry  35.0    male
# 5                                   Moran, Mr. James   NaN    male
# 6                            McCarthy, Mr. Timothy J  54.0    male
# 7                     Palsson, Master. Gosta Leonard   2.0    male
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0  female
# 9                Nasser, Mrs. Nicholas (Adele Achem)  14.0  female

# %%
pd.concat([df1,df2],axis=1)
# Out:
#                                                 Name   Age     Sex  \
# 0                            Braund, Mr. Owen Harris  22.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                             Heikkinen, Miss. Laina  26.0  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                           Allen, Mr. William Henry  35.0    male
# 5                                                NaN   NaN     NaN
# 6                                                NaN   NaN     NaN
# 7                                                NaN   NaN     NaN
# 8                                                NaN   NaN     NaN
# 9                                                NaN   NaN     NaN
#
#                                                 Name   Age     Sex
# 0                                                NaN   NaN     NaN
# 1                                                NaN   NaN     NaN
# ...

# %%
df2.reset_index(drop=True,inplace=True)

# %%
pd.concat([df1,df2],axis=1)
# Out:
#                                                 Name   Age     Sex  \
# 0                            Braund, Mr. Owen Harris  22.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                             Heikkinen, Miss. Laina  26.0  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                           Allen, Mr. William Henry  35.0    male
#
#                                                 Name   Age     Sex
# 0                                   Moran, Mr. James   NaN    male
# 1                            McCarthy, Mr. Timothy J  54.0    male
# 2                     Palsson, Master. Gosta Leonard   2.0    male
# 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0  female
# 4                Nasser, Mrs. Nicholas (Adele Achem)  14.0  female

# %%
df1=pd.DataFrame({
"key1":[1,2,4,5,6],
"key2":[4,5,6,7,8],
"key3":[3,4,5,6,6]

})

# %%
df2=pd.DataFrame({
"key1":[1,2,45,6,67],
"key4":[56,5,6,7,8],
"key5":[3,56,5,6,6]

})

# %%
df1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
df2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
pd.merge(df1,df2,how="inner")
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3    56     3
# 1     2     5     4     5    56
# 2     6     8     6     7     6

# %%
pd.merge(df1,df2,how="left")
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3  56.0   3.0
# 1     2     5     4   5.0  56.0
# 2     4     6     5   NaN   NaN
# 3     5     7     6   NaN   NaN
# 4     6     8     6   7.0   6.0

# %%
pd.merge(df1,df2,how="right")
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0    56     3
# 1     2   5.0   4.0     5    56
# 2    45   NaN   NaN     6     5
# 3     6   8.0   6.0     7     6
# 4    67   NaN   NaN     8     6

# %%
pd.merge(df1,df2,how="outer")
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0  56.0   3.0
# 1     2   5.0   4.0   5.0  56.0
# 2     4   6.0   5.0   NaN   NaN
# 3     5   7.0   6.0   NaN   NaN
# 4     6   8.0   6.0   7.0   6.0
# 5    45   NaN   NaN   6.0   5.0
# 6    67   NaN   NaN   8.0   6.0

# %%
pd.merge(df1,df2,how="cross")
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     4     3       1    56     3
# 1        1     4     3       2     5    56
# 2        1     4     3      45     6     5
# 3        1     4     3       6     7     6
# 4        1     4     3      67     8     6
# 5        2     5     4       1    56     3
# 6        2     5     4       2     5    56
# 7        2     5     4      45     6     5
# 8        2     5     4       6     7     6
# 9        2     5     4      67     8     6
# 10       4     6     5       1    56     3
# 11       4     6     5       2     5    56
# 12       4     6     5      45     6     5
# 13       4     6     5       6     7     6
# 14       4     6     5      67     8     6
# 15       5     7     6       1    56     3
# 16       5     7     6       2     5    56
# 17       5     7     6      45     6     5
# 18       5     7     6       6     7     6
# 19       5     7     6      67     8     6
# 20       6     8     6       1    56     3
# ...

# %%
pd.merge(df1,df2,how="inner",left_on="key2",right_on="key5")
# Out:
#    key1_x  key2  key3  key1_y  key4  key5
# 0       2     5     4      45     6     5
# 1       4     6     5       6     7     6
# 2       4     6     5      67     8     6

# %%
#Join
df1=pd.DataFrame({
"key1":[1,2,4,5,6],
"key2":[4,5,6,7,8],
"key3":[3,4,5,6,6]

},index=['a','b','c','d','e'])

# %%
df2=pd.DataFrame({
"key6":[1,2,45,6,67],
"key4":[56,5,6,7,8],
"key5":[3,56,5,6,6]

},index=['a','b','h','i','j'])

# %%
df1
# Out:
#    key1  key2  key3
# a     1     4     3
# b     2     5     4
# c     4     6     5
# d     5     7     6
# e     6     8     6

# %%
df2
# Out:
#    key6  key4  key5
# a     1    56     3
# b     2     5    56
# h    45     6     5
# i     6     7     6
# j    67     8     6

# %%
df1.join(df2,how="inner")
# Out:
#    key1  key2  key3  key6  key4  key5
# a     1     4     3     1    56     3
# b     2     5     4     2     5    56

# %%
df1.join(df2,how="outer")
# Out:
#    key1  key2  key3  key6  key4  key5
# a   1.0   4.0   3.0   1.0  56.0   3.0
# b   2.0   5.0   4.0   2.0   5.0  56.0
# c   4.0   6.0   5.0   NaN   NaN   NaN
# d   5.0   7.0   6.0   NaN   NaN   NaN
# e   6.0   8.0   6.0   NaN   NaN   NaN
# h   NaN   NaN   NaN  45.0   6.0   5.0
# i   NaN   NaN   NaN   6.0   7.0   6.0
# j   NaN   NaN   NaN  67.0   8.0   6.0

# %%
df1.join(df2,how="left")
# Out:
#    key1  key2  key3  key6  key4  key5
# a     1     4     3   1.0  56.0   3.0
# b     2     5     4   2.0   5.0  56.0
# c     4     6     5   NaN   NaN   NaN
# d     5     7     6   NaN   NaN   NaN
# e     6     8     6   NaN   NaN   NaN

# %%
df1.join(df2,how="right")
# Out:
#    key1  key2  key3  key6  key4  key5
# a   1.0   4.0   3.0     1    56     3
# b   2.0   5.0   4.0     2     5    56
# h   NaN   NaN   NaN    45     6     5
# i   NaN   NaN   NaN     6     7     6
# j   NaN   NaN   NaN    67     8     6

# %%
df1.join(df2,how="cross")
# Out:
#     key1  key2  key3  key6  key4  key5
# 0      1     4     3     1    56     3
# 1      1     4     3     2     5    56
# 2      1     4     3    45     6     5
# 3      1     4     3     6     7     6
# 4      1     4     3    67     8     6
# 5      2     5     4     1    56     3
# 6      2     5     4     2     5    56
# 7      2     5     4    45     6     5
# 8      2     5     4     6     7     6
# 9      2     5     4    67     8     6
# 10     4     6     5     1    56     3
# 11     4     6     5     2     5    56
# 12     4     6     5    45     6     5
# 13     4     6     5     6     7     6
# 14     4     6     5    67     8     6
# 15     5     7     6     1    56     3
# 16     5     7     6     2     5    56
# 17     5     7     6    45     6     5
# 18     5     7     6     6     7     6
# 19     5     7     6    67     8     6
# 20     6     8     6     1    56     3
# 21     6     8     6     2     5    56
# 22     6     8     6    45     6     5
# ...

# %%
#USING APPLY TO APPLY A FUNCTION
df["Fare"]
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
#every value of fare*90
df["Fare_inr"]=df["Fare"].apply(lambda x:x*90)

# %%
df.Fare_inr
# Out:
# 0       652.500
# 1      6415.497
# 2       713.250
# 3      4779.000
# 4       724.500
#          ...
# 886    1170.000
# 887    2700.000
# 888    2110.500
# 889    2700.000
# 890     697.500
# Name: Fare_inr, Length: 891, dtype: float64

# %%
df["Name"].apply(lambda s:len(s))
# Out:
# 0      23
# 1      51
# 2      22
# 3      44
# 4      24
#        ..
# 886    21
# 887    28
# 888    40
# 889    21
# 890    19
# Name: Name, Length: 891, dtype: int64

# %%
def convert(x):
    return x*90
df["Fare"].apply(convert)
# Out:
# 0       652.500
# 1      6415.497
# 2       713.250
# 3      4779.000
# 4       724.500
#          ...
# 886    1170.000
# 887    2700.000
# 888    2110.500
# 889    2700.000
# 890     697.500
# Name: Fare, Length: 891, dtype: float64

# %%
def cathTicekt(x):
    if (x<10):
        return "Cheap"
    elif(x>=10 and x<20):
        return 'Medium'
    else:
        return "High"
df["Catheogrize"]=df["Fare"].apply(cathTicekt)

# %%
df.Catheogrize
# Out:
# 0       Cheap
# 1        High
# 2       Cheap
# 3        High
# 4       Cheap
#         ...
# 886    Medium
# 887      High
# 888      High
# 889      High
# 890     Cheap
# Name: Catheogrize, Length: 891, dtype: object

# %%
df1=pd.DataFrame({
    "a":[1,2,3,4],
    "b":[5,5,6,7]
})

# %%
df1
# Out:
#    a  b
# 0  1  5
# 1  2  5
# 2  3  6
# 3  4  7

# %%
for i in df1.iterrows():#row wise iteration
    print(i)
# Out:
# (0, a    1
# b    5
# Name: 0, dtype: int64)
# (1, a    2
# b    5
# Name: 1, dtype: int64)
# (2, a    3
# b    6
# Name: 2, dtype: int64)
# (3, a    4
# b    7
# Name: 3, dtype: int64)

# %%
for i in df1.items():#col wise iteration
    print(i)
# Out:
# ('a', 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64)
# ('b', 0    5
# 1    5
# 2    6
# 3    7
# Name: b, dtype: int64)

# %%
df1=pd.DataFrame({
    "a":[64,2,97,2],
    "b":[5,5,6,7]
})

# %%
df1
# Out:
#     a  b
# 0  64  5
# 1   2  5
# 2  97  6
# 3   2  7

# %%
df1.sort_values(by="a")
# Out:
#     a  b
# 1   2  5
# 3   2  7
# 0  64  5
# 2  97  6
