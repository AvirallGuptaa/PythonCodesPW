# %%
import numpy as np
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("Travel.csv")

# %%
df
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %%
df.head(5)
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
df.shape
# Out:
# (4888, 20)

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   object
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   object
# ...

# %%
for col in df:
    print(f"{col} has {df[col].unique()} with type {df[col].dtype}\n" )
# Out:
# CustomerID has [200000 200001 200002 ... 204885 204886 204887] with type int64
#
# ProdTaken has [1 0] with type int64
#
# Age has [41. 49. 37. 33. nan 32. 59. 30. 38. 36. 35. 31. 34. 28. 29. 22. 53. 21.
#  42. 44. 46. 39. 24. 43. 50. 27. 26. 48. 55. 45. 56. 23. 51. 40. 54. 58.
#  20. 25. 19. 57. 52. 47. 18. 60. 61.] with type float64
#
# TypeofContact has ['Self Enquiry' 'Company Invited' nan] with type object
#
# CityTier has [3 1 2] with type int64
#
# DurationOfPitch has [  6.  14.   8.   9.  30.  29.  33.  22.  21.  32.  25.  27.  11.  17.
#   15.  13.  12.  16.  10.  31.  18.  nan  24.  35.  28.  20.  26.  34.
#   23.   5.  19. 126.   7.  36. 127.] with type float64
#
# Occupation has ['Salaried' 'Free Lancer' 'Small Business' 'Large Business'] with type object
#
# Gender has ['Female' 'Male' 'Fe Male'] with type object
#
# NumberOfPersonVisiting has [3 2 1 4 5] with type int64
#
# NumberOfFollowups has [ 3.  4.  2.  5. nan  1.  6.] with type float64
#
# ...

# %%
df.Gender.replace(to_replace={"Fe Male":"Female"},inplace=True)

# %%
df.Gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
for col in df:
    print(f"{col} has {df[col].unique()} with type {df[col].dtype}\n" )
# Out:
# CustomerID has [200000 200001 200002 ... 204885 204886 204887] with type int64
#
# ProdTaken has [1 0] with type int64
#
# Age has [41. 49. 37. 33. nan 32. 59. 30. 38. 36. 35. 31. 34. 28. 29. 22. 53. 21.
#  42. 44. 46. 39. 24. 43. 50. 27. 26. 48. 55. 45. 56. 23. 51. 40. 54. 58.
#  20. 25. 19. 57. 52. 47. 18. 60. 61.] with type float64
#
# TypeofContact has ['Self Enquiry' 'Company Invited' nan] with type object
#
# CityTier has [3 1 2] with type int64
#
# DurationOfPitch has [  6.  14.   8.   9.  30.  29.  33.  22.  21.  32.  25.  27.  11.  17.
#   15.  13.  12.  16.  10.  31.  18.  nan  24.  35.  28.  20.  26.  34.
#   23.   5.  19. 126.   7.  36. 127.] with type float64
#
# Occupation has ['Salaried' 'Free Lancer' 'Small Business' 'Large Business'] with type object
#
# Gender has ['Female' 'Male'] with type object
#
# NumberOfPersonVisiting has [3 2 1 4 5] with type int64
#
# NumberOfFollowups has [ 3.  4.  2.  5. nan  1.  6.] with type float64
#
# ...

# %%
(df.isnull().sum().sort_values(ascending=False)  /len(df.index))*100
# Out:
# DurationOfPitch             5.135025
# MonthlyIncome               4.766776
# Age                         4.623568
# NumberOfTrips               2.864157
# NumberOfChildrenVisiting    1.350245
# NumberOfFollowups           0.920622
# PreferredPropertyStar       0.531915
# TypeofContact               0.511457
# CustomerID                  0.000000
# ProdTaken                   0.000000
# Gender                      0.000000
# CityTier                    0.000000
# ProductPitched              0.000000
# NumberOfPersonVisiting      0.000000
# Occupation                  0.000000
# MaritalStatus               0.000000
# PitchSatisfactionScore      0.000000
# Passport                    0.000000
# OwnCar                      0.000000
# Designation                 0.000000
# dtype: float64

# %%
df.dropna(axis=0,inplace=True)

# %%
(df.isnull().sum().sort_values(ascending=False)  /len(df.index))*100
# Out:
# CustomerID                  0.0
# ProdTaken                   0.0
# Age                         0.0
# TypeofContact               0.0
# CityTier                    0.0
# DurationOfPitch             0.0
# Occupation                  0.0
# Gender                      0.0
# NumberOfPersonVisiting      0.0
# NumberOfFollowups           0.0
# ProductPitched              0.0
# PreferredPropertyStar       0.0
# MaritalStatus               0.0
# NumberOfTrips               0.0
# Passport                    0.0
# PitchSatisfactionScore      0.0
# OwnCar                      0.0
# NumberOfChildrenVisiting    0.0
# Designation                 0.0
# MonthlyIncome               0.0
# dtype: float64

# %%
categorical=[]
for col in df.columns:
    if(df[col].dtype=="O"):
        categorical.append(col)

# %%
numerical=[]
for col in df.columns:
    if(df[col].dtype!="O"):
        numerical.append(col)

# %%
categorical
# Out:
# ['TypeofContact',
#  'Occupation',
#  'Gender',
#  'ProductPitched',
#  'MaritalStatus',
#  'Designation']

# %%
numerical
# Out:
# ['CustomerID',
#  'ProdTaken',
#  'Age',
#  'CityTier',
#  'DurationOfPitch',
#  'NumberOfPersonVisiting',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'Passport',
#  'PitchSatisfactionScore',
#  'OwnCar',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %% [markdown]
# # UNIVARIATE

# %%
for col in categorical:
    plt.figure(figsize=(8,5))
    sns.countplot(x=col,data=df)
    plt.title(col)
    plt.show()

# %%
for col in numerical:
    plt.figure(figsize=(8,5))
    sns.histplot(df[col],kde=True)
    plt.title(col)
    plt.show()

# %%
sns.countplot(x =df["TypeofContact"])
# Out:
# <Axes: xlabel='TypeofContact', ylabel='count'>

# %%
df[categorical].describe().T
# Out:
#                count unique           top  freq
# TypeofContact   4128      2  Self Enquiry  2918
# Occupation      4128      4      Salaried  1999
# Gender          4128      2          Male  2463
# ProductPitched  4128      5         Basic  1615
# MaritalStatus   4128      4       Married  1990
# Designation     4128      5     Executive  1615

# %%
for col in categorical:
    print(f"{col}: {df[col].unique()}\n")
# Out:
# TypeofContact: ['Self Enquiry' 'Company Invited']
#
# Occupation: ['Salaried' 'Free Lancer' 'Small Business' 'Large Business']
#
# Gender: ['Female' 'Male']
#
# ProductPitched: ['Deluxe' 'Basic' 'Standard' 'Super Deluxe' 'King']
#
# MaritalStatus: ['Single' 'Divorced' 'Married' 'Unmarried']
#
# Designation: ['Manager' 'Executive' 'Senior Manager' 'AVP' 'VP']

# %%
numerical
# Out:
# ['CustomerID',
#  'ProdTaken',
#  'Age',
#  'CityTier',
#  'DurationOfPitch',
#  'NumberOfPersonVisiting',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'Passport',
#  'PitchSatisfactionScore',
#  'OwnCar',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %%
sns.scatterplot(x="Age",y="DurationOfPitch",data=df,hue="ProdTaken")
# Out:
# <Axes: xlabel='Age', ylabel='DurationOfPitch'>

# %%
cr=pd.crosstab(df["MaritalStatus"],df["ProdTaken"],normalize="index")

# %%
cr
# Out:
# ProdTaken             0         1
# MaritalStatus
# Divorced       0.866920  0.133080
# Married        0.857789  0.142211
# Single         0.635682  0.364318
# Unmarried      0.756598  0.243402

# %%
cr.plot(kind="bar")
# Out:
# <Axes: xlabel='MaritalStatus'>

# %%
sns.barplot(x=df["ProductPitched"],y=df["PitchSatisfactionScore"])
# Out:
# <Axes: xlabel='ProductPitched', ylabel='PitchSatisfactionScore'>

# %%
cx=pd.crosstab(df["MaritalStatus"],df["TypeofContact"],normalize="index")

# %%
cx
# Out:
# TypeofContact  Company Invited  Self Enquiry
# MaritalStatus
# Divorced              0.262357      0.737643
# Married               0.295980      0.704020
# Single                0.301349      0.698651
# Unmarried             0.312317      0.687683

# %%
cx.plot(kind="bar")
# Out:
# <Axes: xlabel='MaritalStatus'>

# %%
sns.violinplot(x=df["ProdTaken"],y="Age",data=df,hue=df["Gender"])
# Out:
# <Axes: xlabel='ProdTaken', ylabel='Age'>

# %%
# sns.swarmplot(x=df["Gender"],y="Age",data=df,hue=df["OwnCar"])

# %%
from mpl_toolkits.mplot3d import Axes3D
fig=plt.figure(figsize=(12,8))
ax=fig.add_subplot(111,projection="3d")
ax.scatter(df["Age"],df["MonthlyIncome"],c=df["DurationOfPitch"])

# %%
numerical
# Out:
# ['CustomerID',
#  'ProdTaken',
#  'Age',
#  'CityTier',
#  'DurationOfPitch',
#  'NumberOfPersonVisiting',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'Passport',
#  'PitchSatisfactionScore',
#  'OwnCar',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %%
num=df.select_dtypes(include="number")
plt.figure(figsize=(12,10))
sns.heatmap(num.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # FEATURE ENGG

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
df.drop("CustomerID",inplace=True,axis=1)

# %%
df.shape
# Out:
# (4128, 19)

# %%
df["TotalVisiting"]=df["NumberOfPersonVisiting"]+df["NumberOfPersonVisiting"]

# %%
df
# Out:
#       ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0             1  41.0     Self Enquiry         3              6.0
# 1             0  49.0  Company Invited         1             14.0
# 2             1  37.0     Self Enquiry         1              8.0
# 3             0  33.0  Company Invited         1              9.0
# 5             0  32.0  Company Invited         1              8.0
# ...         ...   ...              ...       ...              ...
# 4883          1  49.0     Self Enquiry         3              9.0
# 4884          1  28.0  Company Invited         1             31.0
# 4885          1  52.0     Self Enquiry         3             17.0
# 4886          1  19.0     Self Enquiry         3             16.0
# 4887          1  36.0     Self Enquiry         1             14.0
#
#           Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0           Salaried  Female                       3                3.0
# ...

# %%
numerical=[]
for col in df.columns:
    if(df[col].dtype!="O"):
        numerical.append(col)

# %%
numerical
# Out:
# ['ProdTaken',
#  'Age',
#  'CityTier',
#  'DurationOfPitch',
#  'NumberOfPersonVisiting',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'Passport',
#  'PitchSatisfactionScore',
#  'OwnCar',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome',
#  'TotalVisiting']

# %%
categorical=[]
for col in df.columns:
    if(df[col].dtype=="O"):
        categorical.append(col)

# %%
categorical
# Out:
# ['TypeofContact',
#  'Occupation',
#  'Gender',
#  'ProductPitched',
#  'MaritalStatus',
#  'Designation']

# %%
df
# Out:
#       ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0             1  41.0     Self Enquiry         3              6.0
# 1             0  49.0  Company Invited         1             14.0
# 2             1  37.0     Self Enquiry         1              8.0
# 3             0  33.0  Company Invited         1              9.0
# 5             0  32.0  Company Invited         1              8.0
# ...         ...   ...              ...       ...              ...
# 4883          1  49.0     Self Enquiry         3              9.0
# 4884          1  28.0  Company Invited         1             31.0
# 4885          1  52.0     Self Enquiry         3             17.0
# 4886          1  19.0     Self Enquiry         3             16.0
# 4887          1  36.0     Self Enquiry         1             14.0
#
#           Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0           Salaried  Female                       3                3.0
# ...

# %% [markdown]
# # TRAIN TEST

# %%
df.columns
# Out:
# Index(['ProdTaken', 'Age', 'TypeofContact', 'CityTier', 'DurationOfPitch',
#        'Occupation', 'Gender', 'NumberOfPersonVisiting', 'NumberOfFollowups',
#        'ProductPitched', 'PreferredPropertyStar', 'MaritalStatus',
#        'NumberOfTrips', 'Passport', 'PitchSatisfactionScore', 'OwnCar',
#        'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome',
#        'TotalVisiting'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop("ProdTaken",axis=1)
y=df.ProdTaken

# %%
X
# Out:
#        Age    TypeofContact  CityTier  DurationOfPitch      Occupation  \
# 0     41.0     Self Enquiry         3              6.0        Salaried
# 1     49.0  Company Invited         1             14.0        Salaried
# 2     37.0     Self Enquiry         1              8.0     Free Lancer
# 3     33.0  Company Invited         1              9.0        Salaried
# 5     32.0  Company Invited         1              8.0        Salaried
# ...    ...              ...       ...              ...             ...
# 4883  49.0     Self Enquiry         3              9.0  Small Business
# 4884  28.0  Company Invited         1             31.0        Salaried
# 4885  52.0     Self Enquiry         3             17.0        Salaried
# 4886  19.0     Self Enquiry         3             16.0  Small Business
# 4887  36.0     Self Enquiry         1             14.0        Salaried
#
#       Gender  NumberOfPersonVisiting  NumberOfFollowups ProductPitched  \
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 5       0
#        ..
# 4883    1
# 4884    1
# 4885    1
# 4886    1
# 4887    1
# Name: ProdTaken, Length: 4128, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#        Age    TypeofContact  CityTier  DurationOfPitch      Occupation  \
# 3444  53.0     Self Enquiry         1             15.0        Salaried
# 4355  43.0  Company Invited         1             12.0        Salaried
# 1374  58.0     Self Enquiry         3             27.0        Salaried
# 4432  39.0     Self Enquiry         3             14.0  Small Business
# 603   45.0     Self Enquiry         1              8.0        Salaried
# ...    ...              ...       ...              ...             ...
# 3535  34.0     Self Enquiry         1             32.0        Salaried
# 3386  37.0     Self Enquiry         1             17.0  Large Business
# 1160  45.0     Self Enquiry         1              8.0        Salaried
# 4717  35.0  Company Invited         1             10.0        Salaried
# 289   28.0     Self Enquiry         1             14.0        Salaried
#
#       Gender  NumberOfPersonVisiting  NumberOfFollowups ProductPitched  \
# ...

# %%
X_test
# Out:
#        Age    TypeofContact  CityTier  DurationOfPitch      Occupation  \
# 153   45.0     Self Enquiry         1             15.0        Salaried
# 4135  34.0     Self Enquiry         1             11.0  Small Business
# 516   23.0     Self Enquiry         1             10.0  Small Business
# 2626  42.0     Self Enquiry         3             27.0  Small Business
# 907   44.0     Self Enquiry         3             11.0  Small Business
# ...    ...              ...       ...              ...             ...
# 495   27.0     Self Enquiry         3              8.0  Small Business
# 3292  36.0  Company Invited         1             11.0        Salaried
# 3912  50.0  Company Invited         3              9.0  Small Business
# 1932  34.0     Self Enquiry         3             27.0        Salaried
# 2643  39.0     Self Enquiry         1             36.0  Large Business
#
#       Gender  NumberOfPersonVisiting  NumberOfFollowups ProductPitched  \
# ...

# %%
y_train
# Out:
# 3444    0
# 4355    0
# 1374    0
# 4432    0
# 603     0
#        ..
# 3535    0
# 3386    0
# 1160    0
# 4717    0
# 289     0
# Name: ProdTaken, Length: 3302, dtype: int64

# %%
y_test
# Out:
# 153     0
# 4135    0
# 516     0
# 2626    1
# 907     0
#        ..
# 495     1
# 3292    0
# 3912    0
# 1932    0
# 2643    0
# Name: ProdTaken, Length: 826, dtype: int64

# %% [markdown]
# # FEATURE EXTRACTION

# %% [markdown]
# CATEGORICAL- ENCODING
# NUMERICAL- FEATURE SCALING

# %%
numerical
# Out:
# ['ProdTaken',
#  'Age',
#  'CityTier',
#  'DurationOfPitch',
#  'NumberOfPersonVisiting',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'Passport',
#  'PitchSatisfactionScore',
#  'OwnCar',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome',
#  'TotalVisiting']

# %%
categorical
# Out:
# ['TypeofContact',
#  'Occupation',
#  'Gender',
#  'ProductPitched',
#  'MaritalStatus',
#  'Designation']

# %%
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.compose import ColumnTransformer

# %%
numeric_transformer=StandardScaler()
category_transformer=OneHotEncoder(drop ="first")

# %%
preprocessor= ColumnTransformer(
[
    ("OneHotEncoder",category_transformer,categorical),
    ("StandardScaler",numeric_transformer,numerical)
]

)

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('OneHotEncoder', OneHotEncoder(drop='first'),
#                                  ['TypeofContact', 'Occupation', 'Gender',
#                                   'ProductPitched', 'MaritalStatus',
#                                   'Designation']),
#                                 ('StandardScaler', StandardScaler(),
#                                  ['ProdTaken', 'Age', 'CityTier',
#                                   'DurationOfPitch', 'NumberOfPersonVisiting',
#                                   'NumberOfFollowups', 'PreferredPropertyStar',
#                                   'NumberOfTrips', 'Passport',
#                                   'PitchSatisfactionScore', 'OwnCar',
#                                   'NumberOfChildrenVisiting', 'MonthlyIncome',
#                                   'TotalVisiting'])])

# %%
X_train=preprocessor.fit_transform(X_train)

X_test=preprocessor.transform(X_test)
# Out:
# Before transformation: Index(['Age', 'TypeofContact', 'CityTier', 'DurationOfPitch', 'Occupation',
#        'Gender', 'NumberOfPersonVisiting', 'NumberOfFollowups',
#        'ProductPitched', 'PreferredPropertyStar', 'MaritalStatus',
#        'NumberOfTrips', 'Passport', 'PitchSatisfactionScore', 'OwnCar',
#        'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome',
#        'TotalVisiting'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# ...
